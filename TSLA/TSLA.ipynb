# %% [markdown]
# Library

# %%
import yfinance as yf
import numpy as np
from datetime import date, timedelta
import matplotlib.pyplot as plt
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_squared_error, r2_score
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense, Dropout
from tensorflow.keras.optimizers import Adam
from keras.models import load_model

# %% [markdown]
# Import Data

# %%
df = yf.download("TSLA", start = "2020-01-01", end = "2025-05-01")
print(date.today().strftime("%Y-%m-%d"))

data = df['Close'].values

print("Record:",len(data))
print(df.tail())
# Out:
# YF.download() has changed argument auto_adjust default to True
# [*********************100%***********************]  1 of 1 completed
# 2025-05-02
# Record: 1339
# Price            Close        High         Low        Open     Volume
# Ticker            TSLA        TSLA        TSLA        TSLA       TSLA
# Date
# 2025-04-24  259.510010  259.540009  249.199997  250.500000   94464200
# 2025-04-25  284.950012  286.850006  259.630005  261.690002  167560700
# 2025-04-28  285.880005  294.859985  272.420013  288.980011  151731800
# 2025-04-29  292.029999  293.320007  279.470001  285.500000  108906600
# 2025-04-30  282.160004  284.450012  270.779999  279.899994  128961100

# %% [markdown]
# Plot Graph

# %%
plt.figure(figsize = (12, 6))
plt.plot(df.index, data, label = 'Close Price', color = 'blue')
plt.title("Stock Closing Price of TSLA")
plt.xlabel("Date")
plt.ylabel("Price")
plt.grid(True)
plt.legend()
plt.tight_layout()
plt.show()

# %% [markdown]
# Scale Data Into [0,1] and 2D

# %%
scaler = MinMaxScaler()
scaled_data = scaler.fit_transform(data.reshape(-1, 1))

# %% [markdown]
# Split Data and Select Time Step

# %%
time_step = 60
train_size = int(len(scaled_data) * 0.8) 
train_data, test_data = scaled_data[:train_size], scaled_data[train_size:]

X_train, y_train = [], []
X_test, y_test = [], []

for i in range(time_step, len(train_data)):
    X_train.append(train_data[i-time_step:i, 0])
    y_train.append(train_data[i, 0])

for i in range(time_step, len(test_data)):
    X_test.append(test_data[i-time_step:i, 0])
    y_test.append(test_data[i, 0])

X_train, y_train = np.array(X_train), np.array(y_train)
X_test, y_test = np.array(X_test), np.array(y_test)

X_train = X_train.reshape(X_train.shape[0], X_train.shape[1], 1)
X_test = X_test.reshape(X_test.shape[0], X_test.shape[1], 1)
print(len(X_train), len(y_train), len(X_test), len(y_test))
# Out:
# 1011 1011 208 208

# %% [markdown]
# Model LSTM

# %%
model = Sequential()
model.add(LSTM(units = 50, return_sequences = True, input_shape = (X_train.shape[1], 1)))
model.add(LSTM(units = 50, return_sequences = False)) 
model.add(Dense(1))
model.compile(optimizer = "adam", loss = 'mean_squared_error')

# %% [markdown]
# Training Model

# %%
history = model.fit(X_train, y_train, epochs = 50, batch_size = 32, validation_split = 0.2)
# Out:
# Epoch 1/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 4s 54ms/step - loss: 0.0388 - val_loss: 0.0065
# Epoch 2/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 1s 39ms/step - loss: 0.0047 - val_loss: 0.0019
# Epoch 3/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 1s 39ms/step - loss: 0.0026 - val_loss: 0.0014
# Epoch 4/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 1s 39ms/step - loss: 0.0022 - val_loss: 0.0016
# Epoch 5/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 1s 40ms/step - loss: 0.0022 - val_loss: 0.0013
# Epoch 6/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 1s 38ms/step - loss: 0.0021 - val_loss: 0.0014
# Epoch 7/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 1s 39ms/step - loss: 0.0019 - val_loss: 0.0013
# Epoch 8/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 1s 38ms/step - loss: 0.0019 - val_loss: 0.0013
# Epoch 9/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 1s 39ms/step - loss: 0.0017 - val_loss: 0.0014
# Epoch 10/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 1s 42ms/step - loss: 0.0017 - val_loss: 8.7397e-04
# Epoch 11/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 1s 39ms/step - loss: 0.0016 - val_loss: 0.0014
# Epoch 12/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 1s 39ms/step - loss: 0.0015 - val_loss: 8.0173e-04
# Epoch 13/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 1s 38ms/step - loss: 0.0013 - val_loss: 7.5669e-04
# Epoch 14/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 1s 38ms/step - loss: 0.0012 - val_loss: 7.2331e-04
# Epoch 15/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 1s 38ms/step - loss: 0.0011 - val_loss: 6.6997e-04
# Epoch 16/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 1s 40ms/step - loss: 0.0011 - val_loss: 7.7744e-04
# Epoch 17/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 1s 39ms/step - loss: 0.0012 - val_loss: 7.4366e-04
# Epoch 18/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 1s 39ms/step - loss: 0.0011 - val_loss: 6.0510e-04
# Epoch 19/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 1s 38ms/step - loss: 9.9680e-04 - val_loss: 8.0691e-04
# Epoch 20/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 1s 41ms/step - loss: 0.0012 - val_loss: 8.4935e-04
# Epoch 21/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 1s 38ms/step - loss: 0.0011 - val_loss: 5.4811e-04
# Epoch 22/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 1s 37ms/step - loss: 8.9127e-04 - val_loss: 9.6807e-04
# Epoch 23/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 1s 38ms/step - loss: 9.2005e-04 - val_loss: 5.1517e-04
# Epoch 24/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 1s 39ms/step - loss: 9.1647e-04 - val_loss: 5.9497e-04
# Epoch 25/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 1s 40ms/step - loss: 9.2732e-04 - val_loss: 4.8830e-04
# Epoch 26/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 1s 39ms/step - loss: 7.6095e-04 - val_loss: 6.9499e-04
# Epoch 27/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 1s 46ms/step - loss: 8.8966e-04 - val_loss: 5.6435e-04
# Epoch 28/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 1s 43ms/step - loss: 8.6848e-04 - val_loss: 4.5307e-04
# Epoch 29/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 1s 40ms/step - loss: 8.3723e-04 - val_loss: 5.0546e-04
# Epoch 30/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 1s 40ms/step - loss: 7.8376e-04 - val_loss: 6.3381e-04
# Epoch 31/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 1s 40ms/step - loss: 8.8159e-04 - val_loss: 4.5564e-04
# Epoch 32/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 1s 45ms/step - loss: 7.1440e-04 - val_loss: 7.4961e-04
# Epoch 33/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 1s 42ms/step - loss: 7.5839e-04 - val_loss: 6.5280e-04
# Epoch 34/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 1s 38ms/step - loss: 9.5692e-04 - val_loss: 6.0752e-04
# Epoch 35/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 1s 40ms/step - loss: 7.7919e-04 - val_loss: 4.6991e-04
# Epoch 36/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 1s 40ms/step - loss: 8.6088e-04 - val_loss: 5.4836e-04
# Epoch 37/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 1s 43ms/step - loss: 8.0274e-04 - val_loss: 4.7784e-04
# Epoch 38/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 1s 49ms/step - loss: 6.1504e-04 - val_loss: 4.1744e-04
# Epoch 39/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 1s 39ms/step - loss: 8.0188e-04 - val_loss: 3.8641e-04
# Epoch 40/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 1s 41ms/step - loss: 6.8079e-04 - val_loss: 3.8894e-04
# Epoch 41/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 1s 45ms/step - loss: 6.3258e-04 - val_loss: 5.3216e-04
# Epoch 42/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 1s 39ms/step - loss: 6.8331e-04 - val_loss: 4.0970e-04
# Epoch 43/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 1s 40ms/step - loss: 5.8927e-04 - val_loss: 3.7474e-04
# Epoch 44/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 1s 48ms/step - loss: 5.8884e-04 - val_loss: 5.0817e-04
# Epoch 45/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 1s 43ms/step - loss: 7.7226e-04 - val_loss: 3.6142e-04
# Epoch 46/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 1s 42ms/step - loss: 6.0957e-04 - val_loss: 3.7238e-04
# Epoch 47/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 1s 43ms/step - loss: 5.6304e-04 - val_loss: 5.4678e-04
# Epoch 48/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 1s 42ms/step - loss: 6.0347e-04 - val_loss: 4.1426e-04
# Epoch 49/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 1s 46ms/step - loss: 5.4277e-04 - val_loss: 4.2361e-04
# Epoch 50/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 1s 43ms/step - loss: 5.8601e-04 - val_loss: 3.5692e-04

# %% [markdown]
# Check Overfitting

# %%
plt.plot(history.history['loss'], label = 'Training Loss')
plt.plot(history.history['val_loss'], label = 'Validation Loss')
plt.legend()
plt.title("Loss over epochs")
plt.show()

# %%
train_pred = model.predict(X_train)
test_pred = model.predict(X_test)

train_pred_inv = scaler.inverse_transform(train_pred)
y_train_inv = scaler.inverse_transform(y_train.reshape(-1,1))
test_pred_inv = scaler.inverse_transform(test_pred)
y_test_inv = scaler.inverse_transform(y_test.reshape(-1,1))

rmse_train = np.sqrt(mean_squared_error(y_train_inv, train_pred_inv))
rmse_test = np.sqrt(mean_squared_error(y_test_inv, test_pred_inv))
print("Train RMSE:", rmse_train)
print("Test RMSE:", rmse_test)
# Out:
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# Train RMSE: 10.188440898834648
# Test RMSE: 16.568445167999688

# %% [markdown]
# Evalute Model

# %%
predictions = model.predict(X_test)
predictions = scaler.inverse_transform(predictions)
y_test_actual = scaler.inverse_transform(y_test.reshape(-1, 1))
# Out:
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step

# %%
mse = mean_squared_error(y_test_actual, predictions)
rmse = np.sqrt(mse)
r2 = r2_score(y_test_actual, predictions)

print("Mean Squared Error (MSE):", mse)
print("Root Mean Squared Error (RMSE):", rmse)
print("R² Score:", r2)
# Out:
# Mean Squared Error (MSE): 274.51337528501216
# Root Mean Squared Error (RMSE): 16.568445167999688
# R² Score: 0.9496381117998113

# %%
plt.figure(figsize = (12, 6))
plt.plot(y_test_actual, label = "Actual Price", color = 'blue')
plt.plot(predictions, label = "Predicted Price", color = 'red')
plt.title("Actual vs Predicted Stock Prices")
plt.xlabel("Date")
plt.ylabel("Price")
plt.legend()
plt.show()

# %% [markdown]
# Save Model

# %%
model.save("TSLA_model1.h5")
# Out:
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.

# %%
model = load_model("TSLA_model1.h5")
# Out:
# WARNING:absl:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.

# %% [markdown]
# Prediction

# %%
df = yf.download("TSLA", start = "2020-01-01", end = "2025-05-01")
data = df['Close'].values
scaler = MinMaxScaler()
scaled_data = scaler.fit_transform(data.reshape(-1, 1))
# Out:
# [*********************100%***********************]  1 of 1 completed

# %%
time_step = 60
dataf = yf.download("TSLA", period = "61d")
dataf = dataf[:-1]
last_60 = dataf['Close'].values[-time_step:]
last_60_scaled = scaler.transform(last_60.reshape(-1, 1))
X_input = last_60_scaled.reshape(1, time_step, 1)
print(len(last_60))
print(dataf.tail())
# Out:
# [*********************100%***********************]  1 of 1 completed
# 60
# Price            Close        High         Low        Open     Volume
# Ticker            TSLA        TSLA        TSLA        TSLA       TSLA
# Date
# 2025-04-25  284.950012  286.850006  259.630005  261.690002  167560700
# 2025-04-28  285.880005  294.859985  272.420013  288.980011  151731800
# 2025-04-29  292.029999  293.320007  279.470001  285.500000  108906600
# 2025-04-30  282.160004  284.450012  270.779999  279.899994  128961100
# 2025-05-01  280.519989  290.869995  279.809998  280.010010   99122500

# %%
predicted_scaled = model.predict(X_input)
predicted_price = scaler.inverse_transform(predicted_scaled)

print(f"Predicted next closing price:", predicted_price[0][0])

actual_prices = scaler.inverse_transform(scaled_data)

days = [i for i in range(len(actual_prices))]
days_pred = [len(actual_prices)]

plt.figure(figsize = (12, 6))
plt.plot(days, actual_prices, label = 'Actual Price')
plt.plot(days_pred, [predicted_price[0][0]], 'ro', label = 'Predicted Price (Next Day)')
plt.legend()
plt.xlabel("Day")
plt.ylabel("Stock Price")
plt.title("Stock Price Predictio of TSLA")
plt.grid(True)
plt.show()
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 314ms/step
# Predicted next closing price: 289.7833
